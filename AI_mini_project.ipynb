# %% [markdown]
# <a href="https://colab.research.google.com/github/fuzail1011/aiproject/blob/main/AI_mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification to detect sensitive data exposure
#
# ## Importing libraries and downloading the dataset

# %%
# Importing the necessary libraries
import tensorflow as tf
import numpy as np
import os

# Downloading the dataset
git_folder = "/content/aiproject"
if os.path.exists(git_folder) == False:
  # !git clone https://github.com/fuzail1011/aiproject.git

training_folder = git_folder + "/dataset/training"
validation_folder = git_folder + "/dataset/validation"
# Out:
# Cloning into 'aiproject'...
# remote: Enumerating objects: 812, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 812 (delta 1), reused 63 (delta 1), pack-reused 746
# Receiving objects: 100% (812/812), 78.78 MiB | 22.22 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
train_sensitive_dir = os.path.join(training_folder + "/sensitive")
train_nonsensitive_dir = os.path.join(training_folder + "/nonsensitive")
validation_sensitive_dir = os.path.join(validation_folder + "/sensitive")
validation_nonsensitive_dir = os.path.join(validation_folder + "/nonsensitive")

# Image Dataset size
print('Total training sensitive images:', len(os.listdir(train_sensitive_dir)))
print('Total training nonsensitive images:', len(os.listdir(train_nonsensitive_dir)))
print('Total validation sensitive images:', len(os.listdir(validation_sensitive_dir)))
print('Total validation nonsensitive images:', len(os.listdir(validation_nonsensitive_dir)))
# Out:
# Total training sensitive images: 300
# Total training nonsensitive images: 300
# Total validation sensitive images: 50
# Total validation nonsensitive images: 50

# %% [markdown]
# ## Sample Data

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

train_sensitive_dir = os.path.join(training_folder+"/sensitive")
train_nonsensitive_dir = os.path.join(training_folder+"/nonsensitive")
train_sensitive_names = os.listdir(train_sensitive_dir)
train_nonsensitive_names = os.listdir(train_nonsensitive_dir)

pic_index += 8
next_sensitive_pix = [os.path.join(train_sensitive_dir, fname) 
                for fname in train_sensitive_names[pic_index-8:pic_index]]
next_nonsensitive_pix = [os.path.join(train_nonsensitive_dir, fname) 
                for fname in train_nonsensitive_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_sensitive_pix+next_nonsensitive_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Model

# %%
# Callbacks to cancel training after reaching a desired accuracy
# This is done to avoid overfitting
DESIRED_ACCURACY = 0.98

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('accuracy') > DESIRED_ACCURACY:
      print("Reached 98% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# Sequential - defines a SEQUENCE of layers in the neural network.
model = tf.keras.models.Sequential([
  # 2D Convolution Layer - Filter, Kernel_size, activation fn
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
  # Max pooling operation for 2D data - Pool size
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # Flattens the input. Does not affect the batch size.
  tf.keras.layers.Flatten(),
  # Regular densely-connected Neural Network layer with ReLU activation function.
  tf.keras.layers.Dense(512, activation='relu'),
  # Regular densely-connected Neural Network layer with sigmoid activation function.
  tf.keras.layers.Dense(1, activation='sigmoid')
])

from tensorflow.keras.optimizers import RMSprop

# model.compile - Configures the model for training.
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Adam -  optimization algorithm used instead of the classical stochastic gradient descent procedure to update network weights.

# Display the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,969
# Trainable params: 6,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Preprocessing, Data Augmentation & Training

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescaling - 1/255 is to transform every pixel value from range [0,255] -> [0,1]
# Performing image augmentation for training data
train_datagen = ImageDataGenerator(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# flow_from_directory - Takes the path to a directory & generates batches of data.
train_generator = train_datagen.flow_from_directory(
        training_folder,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        validation_folder,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )

num_epochs = 500
# model.fit - Train the model for a fixed number of epochs
history = model.fit(
      train_generator,
      steps_per_epoch=10,
      epochs=num_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# 10/10 [==============================] - 17s 428ms/step - loss: 0.8683 - accuracy: 0.4967 - val_loss: 0.6960 - val_accuracy: 0.4250
# Epoch 2/500
# 10/10 [==============================] - 4s 439ms/step - loss: 0.6800 - accuracy: 0.5200 - val_loss: 0.6370 - val_accuracy: 0.5750
# Epoch 3/500
# 10/10 [==============================] - 4s 445ms/step - loss: 0.6258 - accuracy: 0.6233 - val_loss: 0.5419 - val_accuracy: 0.6750
# Epoch 4/500
# 10/10 [==============================] - 4s 442ms/step - loss: 0.5656 - accuracy: 0.6967 - val_loss: 0.4174 - val_accuracy: 0.8000
# Epoch 5/500
# 10/10 [==============================] - 4s 423ms/step - loss: 0.6252 - accuracy: 0.6500 - val_loss: 0.4739 - val_accuracy: 0.8750
# Epoch 6/500
# 10/10 [==============================] - 4s 434ms/step - loss: 0.5569 - accuracy: 0.7267 - val_loss: 0.3896 - val_accuracy: 0.9250
# Epoch 7/500
# 10/10 [==============================] - 4s 440ms/step - loss: 0.5146 - accuracy: 0.7433 - val_loss: 0.4044 - val_accuracy: 0.8500
# Epoch 8/500
# 10/10 [==============================] - 6s 626ms/step - loss: 0.4683 - accuracy: 0.7633 - val_loss: 0.3791 - val_accuracy: 0.8500
# Epoch 9/500
# 10/10 [==============================] - 4s 439ms/step - loss: 0.4698 - accuracy: 0.7667 - val_loss: 0.3013 - val_accuracy: 0.9000
# Epoch 10/500
# 10/10 [==============================] - 5s 453ms/step - loss: 0.4390 - accuracy: 0.7900 - val_loss: 0.3017 - val_accuracy: 0.8750
# Epoch 11/500
# 10/10 [==============================] - 5s 459ms/step - loss: 0.5526 - accuracy: 0.7133 - val_loss: 0.4364 - val_accuracy: 0.7750
# Epoch 12/500
# 10/10 [==============================] - 4s 432ms/step - loss: 0.5573 - accuracy: 0.7267 - val_loss: 0.5059 - val_accuracy: 0.7750
# Epoch 13/500
# 10/10 [==============================] - 4s 431ms/step - loss: 0.5076 - accuracy: 0.7567 - val_loss: 0.2839 - val_accuracy: 0.9250
# Epoch 14/500
# 10/10 [==============================] - 4s 435ms/step - loss: 0.3791 - accuracy: 0.8300 - val_loss: 0.2308 - val_accuracy: 0.9000
# Epoch 15/500
# 10/10 [==============================] - 4s 433ms/step - loss: 0.5037 - accuracy: 0.7700 - val_loss: 0.2314 - val_accuracy: 1.0000
# Epoch 56/500
# 10/10 [==============================] - 4s 431ms/step - loss: 0.3696 - accuracy: 0.8333 - val_loss: 0.2182 - val_accuracy: 0.9250
# Epoch 57/500
# 10/10 [==============================] - 5s 456ms/step - loss: 0.2953 - accuracy: 0.8900 - val_loss: 0.1308 - val_accuracy: 0.9500
# Epoch 58/500
# 10/10 [==============================] - 4s 441ms/step - loss: 0.2675 - accuracy: 0.8900 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 59/500
# 10/10 [==============================] - 5s 461ms/step - loss: 0.2677 - accuracy: 0.8733 - val_loss: 0.0563 - val_accuracy: 0.9750
# Epoch 60/500
# 10/10 [==============================] - 4s 435ms/step - loss: 0.2810 - accuracy: 0.8733 - val_loss: 0.0977 - val_accuracy: 0.9750
# Epoch 61/500
# 10/10 [==============================] - 4s 455ms/step - loss: 0.2964 - accuracy: 0.8733 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 62/500
# 10/10 [==============================] - 4s 443ms/step - loss: 0.2383 - accuracy: 0.9167 - val_loss: 0.2170 - val_accuracy: 0.9000
# Epoch 63/500
# 10/10 [==============================] - 4s 429ms/step - loss: 0.2009 - accuracy: 0.9300 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 64/500
# 10/10 [==============================] - 4s 415ms/step - loss: 0.2175 - accuracy: 0.9100 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 65/500
# 10/10 [==============================] - 4s 439ms/step - loss: 0.2494 - accuracy: 0.8900 - val_loss: 0.3316 - val_accuracy: 0.8750
# Epoch 66/500
# 10/10 [==============================] - 4s 422ms/step - loss: 0.2668 - accuracy: 0.9067 - val_loss: 0.2915 - val_accuracy: 0.8750
# Epoch 67/500
# 10/10 [==============================] - 4s 441ms/step - loss: 0.2525 - accuracy: 0.9067 - val_loss: 0.1250 - val_accuracy: 1.0000
# Epoch 68/500
# 10/10 [==============================] - 4s 429ms/step - loss: 0.2668 - accuracy: 0.8767 - val_loss: 0.0876 - val_accuracy: 0.9750
# Epoch 69/500
# 10/10 [==============================] - 4s 414ms/step - loss: 0.2101 - accuracy: 0.9267 - val_loss: 0.0513 - val_accuracy: 0.9750
# Epoch 70/500
# 10/10 [==============================] - 4s 422ms/step - loss: 0.2625 - accuracy: 0.8833 - val_loss: 0.0557 - val_accuracy: 0.9750
# Epoch 71/500
# 10/10 [==============================] - 4s 450ms/step - loss: 0.2201 - accuracy: 0.9133 - val_loss: 0.0945 - val_accuracy: 0.9750
# Epoch 72/500
# 10/10 [==============================] - 4s 420ms/step - loss: 0.1898 - accuracy: 0.9333 - val_loss: 0.0559 - val_accuracy: 0.9750
# Epoch 73/500
# 10/10 [==============================] - 4s 415ms/step - loss: 0.1636 - accuracy: 0.9400 - val_loss: 0.1550 - val_accuracy: 0.9750
# Epoch 74/500
# 10/10 [==============================] - 4s 437ms/step - loss: 0.2426 - accuracy: 0.9100 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 75/500
# 10/10 [==============================] - 4s 430ms/step - loss: 0.2311 - accuracy: 0.9100 - val_loss: 0.0428 - val_accuracy: 0.9750
# Epoch 96/500
# 10/10 [==============================] - 4s 431ms/step - loss: 0.1457 - accuracy: 0.9433 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 97/500
# 10/10 [==============================] - 4s 431ms/step - loss: 0.1761 - accuracy: 0.9367 - val_loss: 0.0804 - val_accuracy: 0.9750
# Epoch 98/500
# 10/10 [==============================] - 5s 465ms/step - loss: 0.1342 - accuracy: 0.9500 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 99/500
# 10/10 [==============================] - 4s 430ms/step - loss: 0.2039 - accuracy: 0.8900 - val_loss: 0.0480 - val_accuracy: 0.9500
# Epoch 100/500
# 10/10 [==============================] - 4s 435ms/step - loss: 0.3115 - accuracy: 0.8933 - val_loss: 0.0973 - val_accuracy: 0.9750
# Epoch 101/500
# 10/10 [==============================] - 4s 437ms/step - loss: 0.1567 - accuracy: 0.9400 - val_loss: 0.0798 - val_accuracy: 0.9750
# Epoch 102/500
# 10/10 [==============================] - 5s 454ms/step - loss: 0.1838 - accuracy: 0.9100 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 103/500
# 10/10 [==============================] - 4s 421ms/step - loss: 0.1926 - accuracy: 0.9233 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 104/500
# 10/10 [==============================] - 4s 443ms/step - loss: 0.1802 - accuracy: 0.9100 - val_loss: 0.0838 - val_accuracy: 0.9750
# Epoch 105/500
# 10/10 [==============================] - 4s 423ms/step - loss: 0.1875 - accuracy: 0.9267 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 106/500
# 10/10 [==============================] - 6s 610ms/step - loss: 0.1793 - accuracy: 0.9500 - val_loss: 0.0783 - val_accuracy: 0.9750
# Epoch 107/500
# 10/10 [==============================] - 4s 428ms/step - loss: 0.1623 - accuracy: 0.9367 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 108/500
# 10/10 [==============================] - 4s 439ms/step - loss: 0.1311 - accuracy: 0.9500 - val_loss: 0.1546 - val_accuracy: 0.9000
# Epoch 109/500
# 10/10 [==============================] - 4s 433ms/step - loss: 0.1936 - accuracy: 0.9233 - val_loss: 0.1238 - val_accuracy: 0.9500
# Epoch 110/500
# 10/10 [==============================] - 4s 436ms/step - loss: 0.2366 - accuracy: 0.9033 - val_loss: 0.0769 - val_accuracy: 0.9750
# Epoch 111/500
# 10/10 [==============================] - 5s 452ms/step - loss: 0.1850 - accuracy: 0.9267 - val_loss: 0.0675 - val_accuracy: 0.9500
# Epoch 112/500
# 10/10 [==============================] - 4s 428ms/step - loss: 0.1253 - accuracy: 0.9633 - val_loss: 0.0801 - val_accuracy: 0.9750
# Epoch 113/500
# 10/10 [==============================] - 4s 427ms/step - loss: 0.1097 - accuracy: 0.9567 - val_loss: 0.1622 - val_accuracy: 0.9500
# Epoch 114/500
# 10/10 [==============================] - 4s 423ms/step - loss: 0.1354 - accuracy: 0.9533 - val_loss: 0.1172 - val_accuracy: 0.9500
# Epoch 115/500
# 10/10 [==============================] - 4s 418ms/step - loss: 0.1419 - accuracy: 0.9500 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 116/500
# 10/10 [==============================] - 4s 429ms/step - loss: 0.1123 - accuracy: 0.9567 - val_loss: 0.0481 - val_accuracy: 1.0000
# Epoch 117/500
# 10/10 [==============================] - 4s 412ms/step - loss: 0.1206 - accuracy: 0.9567 - val_loss: 0.2286 - val_accuracy: 0.8750
# Epoch 118/500
# 10/10 [==============================] - 4s 424ms/step - loss: 0.1560 - accuracy: 0.9500 - val_loss: 0.0930 - val_accuracy: 0.9750
# Epoch 119/500
# 10/10 [==============================] - 4s 439ms/step - loss: 0.1049 - accuracy: 0.9700 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 120/500
# 10/10 [==============================] - 5s 476ms/step - loss: 0.1151 - accuracy: 0.9567 - val_loss: 0.0847 - val_accuracy: 0.9500
# Epoch 121/500
# 10/10 [==============================] - 4s 429ms/step - loss: 0.0968 - accuracy: 0.9633 - val_loss: 0.2333 - val_accuracy: 0.9000
# Epoch 122/500
# 10/10 [==============================] - 4s 426ms/step - loss: 0.1518 - accuracy: 0.9400 - val_loss: 0.1181 - val_accuracy: 0.9750
# Epoch 123/500
# 10/10 [==============================] - 4s 445ms/step - loss: 0.0872 - accuracy: 0.9700 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 124/500
# 10/10 [==============================] - 4s 450ms/step - loss: 0.0736 - accuracy: 0.9733 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 125/500
# 10/10 [==============================] - 4s 433ms/step - loss: 0.0891 - accuracy: 0.9733 - val_loss: 0.0357 - val_accuracy: 0.9750
# Epoch 126/500
# 10/10 [==============================] - 4s 431ms/step - loss: 0.1290 - accuracy: 0.9533 - val_loss: 0.0571 - val_accuracy: 0.9750
# Epoch 127/500
# 10/10 [==============================] - 5s 466ms/step - loss: 0.1081 - accuracy: 0.9567 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 128/500
# 10/10 [==============================] - 4s 443ms/step - loss: 0.1174 - accuracy: 0.9633 - val_loss: 0.1200 - val_accuracy: 0.9500
# Epoch 129/500
# 10/10 [==============================] - 4s 453ms/step - loss: 0.1662 - accuracy: 0.9300 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 130/500
# 10/10 [==============================] - 4s 420ms/step - loss: 0.1046 - accuracy: 0.9633 - val_loss: 0.0534 - val_accuracy: 0.9750
# Epoch 131/500
# 10/10 [==============================] - 4s 432ms/step - loss: 0.1417 - accuracy: 0.9500 - val_loss: 0.0821 - val_accuracy: 0.9750
# Epoch 132/500
# 10/10 [==============================] - 5s 460ms/step - loss: 0.0844 - accuracy: 0.9633 - val_loss: 0.0287 - val_accuracy: 0.9750
# Epoch 133/500
# 10/10 [==============================] - 4s 435ms/step - loss: 0.1636 - accuracy: 0.9500 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 134/500
# 10/10 [==============================] - 4s 442ms/step - loss: 0.1337 - accuracy: 0.9367 - val_loss: 0.0392 - val_accuracy: 0.9750
# Epoch 135/500
# 10/10 [==============================] - 4s 424ms/step - loss: 0.1294 - accuracy: 0.9567 - val_loss: 0.0861 - val_accuracy: 0.9750
# Epoch 136/500
# 10/10 [==============================] - 4s 453ms/step - loss: 0.1165 - accuracy: 0.9500 - val_loss: 0.1040 - val_accuracy: 0.9500
# Epoch 137/500
# 10/10 [==============================] - 4s 432ms/step - loss: 0.1161 - accuracy: 0.9500 - val_loss: 0.1140 - val_accuracy: 0.9250
# Epoch 138/500
# 10/10 [==============================] - 4s 428ms/step - loss: 0.1157 - accuracy: 0.9567 - val_loss: 0.0843 - val_accuracy: 0.9750
# Epoch 139/500
# 10/10 [==============================] - 5s 453ms/step - loss: 0.1787 - accuracy: 0.9367 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 140/500
# 10/10 [==============================] - 4s 425ms/step - loss: 0.1060 - accuracy: 0.9500 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 141/500
# 10/10 [==============================] - 4s 420ms/step - loss: 0.1434 - accuracy: 0.9433 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 142/500
# 10/10 [==============================] - 4s 434ms/step - loss: 0.1288 - accuracy: 0.9633 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 143/500
# 10/10 [==============================] - 4s 428ms/step - loss: 0.1250 - accuracy: 0.9567 - val_loss: 0.1261 - val_accuracy: 0.9500
# Epoch 144/500
# 10/10 [==============================] - 4s 447ms/step - loss: 0.1443 - accuracy: 0.9567 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 145/500
# 10/10 [==============================] - 4s 442ms/step - loss: 0.0566 - accuracy: 0.9767 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 146/500
# 10/10 [==============================] - 4s 440ms/step - loss: 0.1104 - accuracy: 0.9667 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 147/500
# 10/10 [==============================] - 4s 434ms/step - loss: 0.0782 - accuracy: 0.9667 - val_loss: 0.0619 - val_accuracy: 0.9750
# Epoch 148/500
# 10/10 [==============================] - 4s 416ms/step - loss: 0.1026 - accuracy: 0.9633 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 149/500
# 10/10 [==============================] - 4s 412ms/step - loss: 0.1300 - accuracy: 0.9467 - val_loss: 0.1234 - val_accuracy: 0.9750
# Epoch 150/500
# 10/10 [==============================] - 4s 430ms/step - loss: 0.1189 - accuracy: 0.9433 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 151/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9833Reached 98% accuracy so cancelling training!
# 10/10 [==============================] - 4s 417ms/step - loss: 0.0580 - accuracy: 0.9833 - val_loss: 0.0320 - val_accuracy: 1.0000

# %% [markdown]
# ## Plotting Accuracy and Loss Functions

# %%
import matplotlib.pyplot as plt

# Plot the accuracy and loss functions
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn
y_pred = model.predict(validation_generator, 20)
print('Confusion Matrix')
y_predicted_labels = y_pred > 0.5

size = np.size(y_predicted_labels)
y_predicted_labels = y_predicted_labels.reshape(size, )

for i in range (1, 5):
  total = i * size // 4
  mid = 49
  start = mid-((total+1)//2)+1
  end = mid+((total+1)//2)
  cm = tf.math.confusion_matrix(labels=validation_generator.labels[start:end],predictions=y_predicted_labels[start:end])

  # Calculate accuracy
  cm_np = cm.numpy()
  conf_acc = (cm_np[0, 0] + cm_np[1, 1])/ np.sum(cm_np) * 100
  print("Accuracy for", str(total), "Test Data = ", conf_acc)

  # Plot the confusion matrix
  plt.figure(figsize = (10,7))
  seaborn.heatmap(cm, annot=True, fmt='d')
  plt.title("Confusion Matrix for " + str(total) + " Test Data")
  plt.xlabel('Predicted')
  plt.ylabel('Expected')
# Out:
# Confusion Matrix
# Accuracy for 25 Test Data =  28.000000000000004
# Accuracy for 50 Test Data =  32.6530612244898
# Accuracy for 75 Test Data =  36.0
# Accuracy for 100 Test Data =  38.38383838383838

# %% [markdown]
# ## Saving the model

# %%
# Save and convert the model (Used for deploying in web application)
model.save('model/image_model.h5')
print("Saved the model successfully")

# !apt-get -qq install virtualenv
# !virtualenv -p python3 venv
# !source venv/bin/activate
# !pip install -q tensorflowjs
# !tensorflowjs_converter --input_format=keras /content/model/image_model.h5 /content/image_model
print("Model converted to JSON successfully")
# Out:
# Saved the model successfully
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_9.0.1-2.3~ubuntu1.18.04.5_all.deb ...
# Unpacking python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-virtualenv.
# Preparing to unpack .../python3-virtualenv_15.1.0+ds-1.1_all.deb ...
# Unpacking python3-virtualenv (15.1.0+ds-1.1) ...
# Selecting previously unselected package virtualenv.
# Preparing to unpack .../virtualenv_15.1.0+ds-1.1_all.deb ...
# Unpacking virtualenv (15.1.0+ds-1.1) ...
# Setting up python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up python3-virtualenv (15.1.0+ds-1.1) ...
# Setting up virtualenv (15.1.0+ds-1.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Already using interpreter /usr/bin/python3
# Using base prefix '/usr'
# New python executable in /content/venv/bin/python3
# Also creating executable in /content/venv/bin/python
# Installing setuptools, pkg_resources, pip, wheel...done.
#      |████████████████████████████████| 77 kB 3.2 MB/s
#      |████████████████████████████████| 462 kB 27.2 MB/s
# Model converted to JSON successfully

# %% [markdown]
# ## Sample Example

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()
result = dict()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " - Sensitive")
    result[fn] = "Sensitive"
  else:
    print(fn + " - Non-sensitive")
    result[fn] = "Non-sensitive"

plt.figure(figsize=(20,20))
   
for i, fn in enumerate(uploaded.keys()):
  image = plt.imread(fn)  
  plt.subplot(5, 5, i+1)
  plt.axis("off")
  plt.imshow(image)
  ans = fn + ": " + result[fn]
  plt.title(ans)
# Out:
#      <input type="file" id="files-4fd0ad1a-1ecf-4c1f-a934-0e3f3423067b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fd0ad1a-1ecf-4c1f-a934-0e3f3423067b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving COCO_train2014_000000000049.jpg to COCO_train2014_000000000049.jpg
# [0.]
# COCO_train2014_000000000049.jpg - Non-sensitive
